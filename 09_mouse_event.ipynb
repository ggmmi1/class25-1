# %% [markdown]
# 09. 마우스 이벤트

# %%
import cv2

# %%
def on_mouse(event, x, y, flags, _):
    print(x,y)

img = cv2.imread("images/Unknown.jpeg")
name = "Mouse event"

cv2.namedWindow(name)
cv2.setMouseCallback(name, on_mouse)
cv2.imshow(name, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 215 149
# 157 129
# 125 116
# 71 93
# 63 89
# 25 64
# 23 61
# 16 55
# 14 52
# 13 51
# 13 50
# 13 49
# 13 49
# 13 49
# 12 49
# 12 48
# 11 48
# 11 48
# 10 47
# 10 47
# 9 46
# 9 46
# 8 46
# 8 45
# 7 45
# 7 44
# 6 44
# 6 45
# 6 45
# 6 45
# 7 46
# 7 46
# 7 46
# 8 46
# 8 46
# 8 46
# 9 46
# 9 47
# 9 47
# 10 47
# 10 47
# 10 47
# 11 48
# 11 48
# 11 48
# 12 48
# 12 49
# 12 49
# 13 49
# 13 49
# 14 49
# 14 49
# 16 50
# 16 50
# 18 51
# 19 52
# 21 55
# 23 56
# 24 57
# 27 61
# 28 63
# 29 66
# 31 69
# 32 71
# 32 73
# 33 76
# 33 78
# 33 80
# 32 85
# 31 87
# 26 92
# 25 94
# 23 96
# 16 102
# 15 104
# 12 106
# 5 111
# 2 114
# 0 119
# 0 121
# 0 122
# 0 123
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 124
# 0 123
# 0 123
# 0 122
# 0 121
# 0 121
# 0 119
# 0 119
# 0 117
# 2 116
# 4 114
# 13 111
# 16 110
# 20 109
# 24 109
# 27 109
# 35 109
# 38 109
# 44 111
# 47 114
# 48 115
# 53 120
# 57 126
# 58 129
# 58 130
# 59 134
# 59 136
# 58 140
# 56 142
# 55 143
# 46 149
# 37 152
# 32 153
# 25 154
# 13 155
# 6 156
# 1 156
# 0 155
# 0 152
# 0 149
# 0 147
# 0 143
# 0 140
# 0 134
# 0 133
# 0 130
# 0 126
# 0 124
# 0 122
# 0 118
# 0 113
# 0 111
# 0 104
# 0 102
# 0 98
# 3 91
# 6 85
# 9 81
# 10 80
# 15 75
# 18 73
# 24 71
# 27 70
# 35 69
# 39 69
# 43 68
# 52 68
# 61 68
# 64 69
# 67 70
# 71 73
# 73 74
# 75 76
# 77 78
# 78 79
# 79 83
# 79 86
# 80 91
# 80 98
# 80 102
# 79 110
# 77 114
# 74 122
# 72 126
# 70 130
# 64 137
# 60 141
# 52 146
# 40 151
# 26 153
# 19 154
# 4 155
# 0 155
# 0 153
# 0 148
# 0 146
# 0 144
# 0 140
# 0 138
# 0 133
# 0 132
# 0 130
# 0 126
# 0 124
# 0 118
# 0 114
# 0 108
# 1 104
# 2 100
# 5 93
# 9 85
# 11 82
# 13 80
# 17 77
# 21 75
# 23 75
# 27 75
# 29 75
# 31 75
# 39 75
# 41 75
# 48 77
# 51 78
# 63 86
# 70 91
# 73 95
# 77 98
# 83 107
# 85 111
# 88 116
# 93 125
# 94 129
# 96 135
# 97 139
# 97 143
# 98 148
# 98 153
# 96 158
# 94 161
# 91 164
# 80 171
# 70 174
# 57 178
# 32 181
# 22 181
# 12 181
# 0 181
# 0 176
# 0 175
# 0 173
# 0 166
# 0 165
# 0 158
# 0 155
# 0 152
# 0 145
# 0 141
# 2 132
# 4 126
# 10 110
# 15 99
# 17 94
# 20 88
# 22 85
# 24 82
# 27 78
# 29 76
# 32 75
# 33 74
# 34 74
# 38 73
# 40 73
# 47 73
# 51 73
# 62 75
# 67 77
# 75 80
# 78 82
# 82 85
# 87 90
# 89 91
# 93 97
# 95 100
# 96 103
# 98 109
# 99 112
# 99 118
# 99 122
# 99 126
# 99 132
# 98 135
# 93 143
# 90 147
# 80 156
# 73 159
# 65 163
# 50 167
# 23 171
# 15 171
# 6 171
# 0 170
# 0 161
# 0 158
# 0 155
# 0 146
# 0 142
# 0 134
# 0 129
# 0 127
# 0 115
# 0 114
# 0 105
# 0 102
# 3 95
# 11 85
# 13 82
# 16 78
# 22 73
# 26 71
# 34 69
# 38 69
# 48 69
# 53 69
# 69 79
# 76 85
# 95 102
# 102 111
# 109 121
# 117 135
# 126 152
# 129 169
# 132 179
# 132 196
# 132 203
# 131 216
# 128 221
# 0 210
# 0 187
# 0 182
# 0 171
# 0 167
# 2 159
# 2 157
# 7 149
# 13 141
# 15 139
# 16 137
# 20 134
# 21 133
# 24 132
# 25 132
# 26 132
# 28 132
# 28 132
# 30 132
# 31 132
# 34 132
# 37 132
# 38 132
# 41 133
# 43 134
# 46 135
# 47 136
# 49 138
# 50 139
# 51 140
# 52 143
# 52 144
# 53 145
# 53 146
# 53 148
# 53 149
# 53 151
# 53 152
# 53 153
# 51 155
# 49 156
# 47 157
# 42 159
# 38 160
# 36 160
# 26 163
# 23 163
# 14 165
# 10 165
# 5 165
# 0 165
# 0 165
# 0 165
# 0 164
# 0 161
# 0 160
# 0 158
# 0 155
# 0 153
# 0 152
# 0 150
# 0 150
# 0 149

# %%
#클릭한 곳에 원 그리기 (연속적으로 찍히기, 얕은 복사)

img = cv2.imread("images/Unknown.jpeg")

def on_mouse(event, x, y, flags, _):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img, (x,y), 3, (255, 255, 0), cv2.FILLED)#원을 찍은 뒤
        cv2. imshow(name, img) #화면을 다시 그려준다
  

name = "Mouse event"

cv2.namedWindow(name)
cv2.setMouseCallback(name, on_mouse)
cv2.imshow(name, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2025-01-06 10:16:53.073 Python[39621:3250217] error messaging the mach port for IMKCFRunLoopWakeUpReliable

# %%
#클릭한 곳에 원 그리기 (찍은 것만 실시간으로 보이기)

img = cv2.imread("images/Unknown.jpeg")
name = "Mouse event"
cv2.namedWindow(name)

def on_mouse(event, x, y, flags, _):
    if event == cv2.EVENT_LBUTTONDOWN:
        copied = img.copy() #깊은 복사 
        cv2.circle(copied, (x,y), 3, (255, 255, 0), cv2.FILLED)#원을 찍은 뒤
        cv2. imshow(name, copied) #화면을 다시 그려준다
  

cv2.setMouseCallback(name, on_mouse)
cv2.imshow(name, img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 미니프로젝트 -1 반자동 문서 스캐너 만들기
# - 이미지를 시계방향으로 클릭하면
# - 이미지에 점이 찍히고
# - 점과 점 사이에 라인이 연결
# - 4개의 점을 찍으면 해당 영역이 펼쳐지도록 구현

# %%
import cv2
import numpy as np

img = cv2.imread("images/card.jpg")
point_list = []

# 최종 결과를 출력하는 함수입니다
def show_result():
  width, height = 600, 350
  src = np.array(point_list, dtype=np.float32)
  # src = np.float32(point_list)
  target = np.array([[0,0], [width, 0], [width, height], [0, height]], dtype=np.float32)
  mat = cv2.getPerspectiveTransform(src, target)
  result = cv2.warpPerspective(img, mat, (width, height))
  cv2.imshow("result", result)

# 마우스 이벤트와 함께 실행되는 콜백함수입니다.
drawing = False
def on_mouse(event, x, y, flags, _):
  global drawing
  coppied = img.copy()
  if event == cv2.EVENT_LBUTTONDOWN:
    drawing = True
    point_list.append((x,y))

  if drawing:
    prev_point = None
    for point in point_list:
      cv2.circle(coppied, point, 10, (0,0,255), cv2.FILLED)
      if prev_point:
        cv2.line(coppied, prev_point, point, (0,0,255), 5)
      prev_point = point

    next_point = (x,y)
    if len(point_list) == 4:
      next_point = point_list[0]
      show_result()
    cv2.line(coppied, point_list[-1], next_point, (0,0,255), 5)

  cv2.imshow(name, coppied)

# 기본적인 코드 실행입니다.
name = "Scanner"
cv2.namedWindow(name)
cv2.setMouseCallback(name, on_mouse)
cv2.imshow(name, img)
cv2.waitKey(0)
cv2.destroyAllWindows()
